# %% [markdown]
# # Week 5 Homework
#
# ***Due (pushed to your GitHub branch) on 10/18 by 11:59 pm***

# %% [markdown]
# ## FASTQ fetch, QC, and trimming/filtering
#
# Use the SRA-toolkit to fetch the relevant FASTQ files. You may use a hand-crafted `txt` file to provide the list of SRAs instead of manipulating an SRA Run Table with `cut`.

# %% [markdown]
# Run QC on the FASTQ files and aggregate the results into a report.

# %%
# !mkdir fastq_Placenta
# !cut -d ',' -f 1 SraRunTable_Placenta.txt | tail -n +2 > sra_list_placenta.txt
# !while IFS= read -r line; do \
    echo "Getting $line from NCBI SRA"; \
    parallel-fastq-dump --sra-id $line --threads 16 --outdir fastq --gzip; \
    done < sra_list_placenta.txt
# Out:
# Getting ERR4231022 from NCBI SRA
# 2024-10-10 15:52:42,588 - SRR ids: ['ERR4231022']
# 2024-10-10 15:52:42,588 - extra args: ['--gzip']
# 2024-10-10 15:52:42,589 - tempdir: /local/scratch/job_98763/pfd_wkp5_n_8
# 2024-10-10 15:52:42,589 - CMD: sra-stat --meta --quick ERR4231022
# 2024-10-10 15:52:44,994 - ERR4231022 spots: 55208970
# 2024-10-10 15:52:44,994 - blocks: [[1, 3450560], [3450561, 6901120], [6901121, 10351680], [10351681, 13802240], [13802241, 17252800], [17252801, 20703360], [20703361, 24153920], [24153921, 27604480], [27604481, 31055040], [31055041, 34505600], [34505601, 37956160], [37956161, 41406720], [41406721, 44857280], [44857281, 48307840], [48307841, 51758400], [51758401, 55208970]]
# 2024-10-10 15:52:44,994 - CMD: fastq-dump -N 1 -X 3450560 -O /local/scratch/job_98763/pfd_wkp5_n_8/0 --gzip ERR4231022
# 2024-10-10 15:52:44,995 - CMD: fastq-dump -N 3450561 -X 6901120 -O /local/scratch/job_98763/pfd_wkp5_n_8/1 --gzip ERR4231022
# 2024-10-10 15:52:44,996 - CMD: fastq-dump -N 6901121 -X 10351680 -O /local/scratch/job_98763/pfd_wkp5_n_8/2 --gzip ERR4231022
# 2024-10-10 15:52:44,996 - CMD: fastq-dump -N 10351681 -X 13802240 -O /local/scratch/job_98763/pfd_wkp5_n_8/3 --gzip ERR4231022
# 2024-10-10 15:52:44,997 - CMD: fastq-dump -N 13802241 -X 17252800 -O /local/scratch/job_98763/pfd_wkp5_n_8/4 --gzip ERR4231022
# 2024-10-10 15:52:44,997 - CMD: fastq-dump -N 17252801 -X 20703360 -O /local/scratch/job_98763/pfd_wkp5_n_8/5 --gzip ERR4231022
# 2024-10-10 15:52:44,997 - CMD: fastq-dump -N 20703361 -X 24153920 -O /local/scratch/job_98763/pfd_wkp5_n_8/6 --gzip ERR4231022
# 2024-10-10 15:52:44,997 - CMD: fastq-dump -N 24153921 -X 27604480 -O /local/scratch/job_98763/pfd_wkp5_n_8/7 --gzip ERR4231022
# 2024-10-10 15:52:44,998 - CMD: fastq-dump -N 27604481 -X 31055040 -O /local/scratch/job_98763/pfd_wkp5_n_8/8 --gzip ERR4231022
# 2024-10-10 15:52:44,998 - CMD: fastq-dump -N 31055041 -X 34505600 -O /local/scratch/job_98763/pfd_wkp5_n_8/9 --gzip ERR4231022
# 2024-10-10 15:52:44,998 - CMD: fastq-dump -N 34505601 -X 37956160 -O /local/scratch/job_98763/pfd_wkp5_n_8/10 --gzip ERR4231022
# 2024-10-10 15:52:44,999 - CMD: fastq-dump -N 37956161 -X 41406720 -O /local/scratch/job_98763/pfd_wkp5_n_8/11 --gzip ERR4231022
# 2024-10-10 15:52:44,999 - CMD: fastq-dump -N 41406721 -X 44857280 -O /local/scratch/job_98763/pfd_wkp5_n_8/12 --gzip ERR4231022
# 2024-10-10 15:52:44,999 - CMD: fastq-dump -N 44857281 -X 48307840 -O /local/scratch/job_98763/pfd_wkp5_n_8/13 --gzip ERR4231022
# 2024-10-10 15:52:44,999 - CMD: fastq-dump -N 48307841 -X 51758400 -O /local/scratch/job_98763/pfd_wkp5_n_8/14 --gzip ERR4231022
# 2024-10-10 15:52:45,000 - CMD: fastq-dump -N 51758401 -X 55208970 -O /local/scratch/job_98763/pfd_wkp5_n_8/15 --gzip ERR4231022
# Read 3450560 spots for ERR4231022
# Written 3450560 spots for ERR4231022
# Read 3450560 spots for ERR4231022
# Written 3450560 spots for ERR4231022
# Read 3450560 spots for ERR4231022
# Written 3450560 spots for ERR4231022
# Read 3450560 spots for ERR4231022
# Written 3450560 spots for ERR4231022
# Read 3450560 spots for ERR4231022
# Written 3450560 spots for ERR4231022
# Read 3450570 spots for ERR4231022
# Written 3450570 spots for ERR4231022
# Read 3450560 spots for ERR4231022
# Written 3450560 spots for ERR4231022
# Read 3450560 spots for ERR4231022
# Written 3450560 spots for ERR4231022
# Read 3450560 spots for ERR4231022
# Written 3450560 spots for ERR4231022
# Read 3450560 spots for ERR4231022
# Written 3450560 spots for ERR4231022
# Read 3450560 spots for ERR4231022
# Written 3450560 spots for ERR4231022
# Read 3450560 spots for ERR4231022
# Written 3450560 spots for ERR4231022
# Read 3450560 spots for ERR4231022
# Written 3450560 spots for ERR4231022
# Read 3450560 spots for ERR4231022
# Written 3450560 spots for ERR4231022
# Read 3450560 spots for ERR4231022
# Written 3450560 spots for ERR4231022
# Read 3450560 spots for ERR4231022
# Written 3450560 spots for ERR4231022
# Getting ERR4231010 from NCBI SRA
# 2024-10-10 16:00:18,822 - SRR ids: ['ERR4231010']
# 2024-10-10 16:00:18,822 - extra args: ['--gzip']
# 2024-10-10 16:00:18,822 - tempdir: /local/scratch/job_98763/pfd_yfmlne_s
# 2024-10-10 16:00:18,822 - CMD: sra-stat --meta --quick ERR4231010
# 2024-10-10 16:00:21,195 - ERR4231010 spots: 64341577
# 2024-10-10 16:00:21,195 - blocks: [[1, 4021348], [4021349, 8042696], [8042697, 12064044], [12064045, 16085392], [16085393, 20106740], [20106741, 24128088], [24128089, 28149436], [28149437, 32170784], [32170785, 36192132], [36192133, 40213480], [40213481, 44234828], [44234829, 48256176], [48256177, 52277524], [52277525, 56298872], [56298873, 60320220], [60320221, 64341577]]
# 2024-10-10 16:00:21,195 - CMD: fastq-dump -N 1 -X 4021348 -O /local/scratch/job_98763/pfd_yfmlne_s/0 --gzip ERR4231010
# 2024-10-10 16:00:21,196 - CMD: fastq-dump -N 4021349 -X 8042696 -O /local/scratch/job_98763/pfd_yfmlne_s/1 --gzip ERR4231010
# 2024-10-10 16:00:21,197 - CMD: fastq-dump -N 8042697 -X 12064044 -O /local/scratch/job_98763/pfd_yfmlne_s/2 --gzip ERR4231010
# 2024-10-10 16:00:21,197 - CMD: fastq-dump -N 12064045 -X 16085392 -O /local/scratch/job_98763/pfd_yfmlne_s/3 --gzip ERR4231010
# 2024-10-10 16:00:21,198 - CMD: fastq-dump -N 16085393 -X 20106740 -O /local/scratch/job_98763/pfd_yfmlne_s/4 --gzip ERR4231010
# 2024-10-10 16:00:21,198 - CMD: fastq-dump -N 20106741 -X 24128088 -O /local/scratch/job_98763/pfd_yfmlne_s/5 --gzip ERR4231010
# 2024-10-10 16:00:21,198 - CMD: fastq-dump -N 24128089 -X 28149436 -O /local/scratch/job_98763/pfd_yfmlne_s/6 --gzip ERR4231010
# 2024-10-10 16:00:21,199 - CMD: fastq-dump -N 28149437 -X 32170784 -O /local/scratch/job_98763/pfd_yfmlne_s/7 --gzip ERR4231010
# 2024-10-10 16:00:21,199 - CMD: fastq-dump -N 32170785 -X 36192132 -O /local/scratch/job_98763/pfd_yfmlne_s/8 --gzip ERR4231010
# 2024-10-10 16:00:21,199 - CMD: fastq-dump -N 36192133 -X 40213480 -O /local/scratch/job_98763/pfd_yfmlne_s/9 --gzip ERR4231010
# 2024-10-10 16:00:21,204 - CMD: fastq-dump -N 40213481 -X 44234828 -O /local/scratch/job_98763/pfd_yfmlne_s/10 --gzip ERR4231010
# 2024-10-10 16:00:21,204 - CMD: fastq-dump -N 44234829 -X 48256176 -O /local/scratch/job_98763/pfd_yfmlne_s/11 --gzip ERR4231010
# 2024-10-10 16:00:21,205 - CMD: fastq-dump -N 48256177 -X 52277524 -O /local/scratch/job_98763/pfd_yfmlne_s/12 --gzip ERR4231010
# 2024-10-10 16:00:21,206 - CMD: fastq-dump -N 52277525 -X 56298872 -O /local/scratch/job_98763/pfd_yfmlne_s/13 --gzip ERR4231010
# 2024-10-10 16:00:21,208 - CMD: fastq-dump -N 56298873 -X 60320220 -O /local/scratch/job_98763/pfd_yfmlne_s/14 --gzip ERR4231010
# 2024-10-10 16:00:21,260 - CMD: fastq-dump -N 60320221 -X 64341577 -O /local/scratch/job_98763/pfd_yfmlne_s/15 --gzip ERR4231010
# Read 4021348 spots for ERR4231010
# Written 4021348 spots for ERR4231010
# Read 4021348 spots for ERR4231010
# Written 4021348 spots for ERR4231010
# Read 4021348 spots for ERR4231010
# Written 4021348 spots for ERR4231010
# Read 4021348 spots for ERR4231010
# Written 4021348 spots for ERR4231010
# Read 4021348 spots for ERR4231010
# Written 4021348 spots for ERR4231010
# Read 4021348 spots for ERR4231010
# Written 4021348 spots for ERR4231010
# Read 4021348 spots for ERR4231010
# Written 4021348 spots for ERR4231010
# Read 4021348 spots for ERR4231010
# Written 4021348 spots for ERR4231010
# Read 4021348 spots for ERR4231010
# Written 4021348 spots for ERR4231010
# Read 4021357 spots for ERR4231010
# Written 4021357 spots for ERR4231010
# Read 4021348 spots for ERR4231010
# Written 4021348 spots for ERR4231010
# Read 4021348 spots for ERR4231010
# Written 4021348 spots for ERR4231010
# Read 4021348 spots for ERR4231010
# Written 4021348 spots for ERR4231010
# Read 4021348 spots for ERR4231010
# Written 4021348 spots for ERR4231010
# Read 4021348 spots for ERR4231010
# Written 4021348 spots for ERR4231010
# Read 4021348 spots for ERR4231010
# Written 4021348 spots for ERR4231010
# Getting ERR4231012 from NCBI SRA
# 2024-10-10 16:09:30,914 - SRR ids: ['ERR4231012']
# 2024-10-10 16:09:30,914 - extra args: ['--gzip']
# 2024-10-10 16:09:30,914 - tempdir: /local/scratch/job_98763/pfd_h6mp91h7
# 2024-10-10 16:09:30,914 - CMD: sra-stat --meta --quick ERR4231012
# 2024-10-10 16:09:33,377 - ERR4231012 spots: 73535954
# 2024-10-10 16:09:33,377 - blocks: [[1, 4595997], [4595998, 9191994], [9191995, 13787991], [13787992, 18383988], [18383989, 22979985], [22979986, 27575982], [27575983, 32171979], [32171980, 36767976], [36767977, 41363973], [41363974, 45959970], [45959971, 50555967], [50555968, 55151964], [55151965, 59747961], [59747962, 64343958], [64343959, 68939955], [68939956, 73535954]]
# 2024-10-10 16:09:33,378 - CMD: fastq-dump -N 1 -X 4595997 -O /local/scratch/job_98763/pfd_h6mp91h7/0 --gzip ERR4231012
# 2024-10-10 16:09:33,378 - CMD: fastq-dump -N 4595998 -X 9191994 -O /local/scratch/job_98763/pfd_h6mp91h7/1 --gzip ERR4231012
# 2024-10-10 16:09:33,379 - CMD: fastq-dump -N 9191995 -X 13787991 -O /local/scratch/job_98763/pfd_h6mp91h7/2 --gzip ERR4231012
# 2024-10-10 16:09:33,379 - CMD: fastq-dump -N 13787992 -X 18383988 -O /local/scratch/job_98763/pfd_h6mp91h7/3 --gzip ERR4231012
# 2024-10-10 16:09:33,379 - CMD: fastq-dump -N 18383989 -X 22979985 -O /local/scratch/job_98763/pfd_h6mp91h7/4 --gzip ERR4231012
# 2024-10-10 16:09:33,380 - CMD: fastq-dump -N 22979986 -X 27575982 -O /local/scratch/job_98763/pfd_h6mp91h7/5 --gzip ERR4231012
# 2024-10-10 16:09:33,380 - CMD: fastq-dump -N 27575983 -X 32171979 -O /local/scratch/job_98763/pfd_h6mp91h7/6 --gzip ERR4231012
# 2024-10-10 16:09:33,382 - CMD: fastq-dump -N 32171980 -X 36767976 -O /local/scratch/job_98763/pfd_h6mp91h7/7 --gzip ERR4231012
# 2024-10-10 16:09:33,383 - CMD: fastq-dump -N 36767977 -X 41363973 -O /local/scratch/job_98763/pfd_h6mp91h7/8 --gzip ERR4231012
# 2024-10-10 16:09:33,389 - CMD: fastq-dump -N 41363974 -X 45959970 -O /local/scratch/job_98763/pfd_h6mp91h7/9 --gzip ERR4231012
# 2024-10-10 16:09:33,390 - CMD: fastq-dump -N 45959971 -X 50555967 -O /local/scratch/job_98763/pfd_h6mp91h7/10 --gzip ERR4231012
# 2024-10-10 16:09:33,391 - CMD: fastq-dump -N 50555968 -X 55151964 -O /local/scratch/job_98763/pfd_h6mp91h7/11 --gzip ERR4231012
# 2024-10-10 16:09:33,401 - CMD: fastq-dump -N 55151965 -X 59747961 -O /local/scratch/job_98763/pfd_h6mp91h7/12 --gzip ERR4231012
# 2024-10-10 16:09:33,440 - CMD: fastq-dump -N 59747962 -X 64343958 -O /local/scratch/job_98763/pfd_h6mp91h7/13 --gzip ERR4231012
# 2024-10-10 16:09:33,441 - CMD: fastq-dump -N 64343959 -X 68939955 -O /local/scratch/job_98763/pfd_h6mp91h7/14 --gzip ERR4231012
# 2024-10-10 16:09:33,441 - CMD: fastq-dump -N 68939956 -X 73535954 -O /local/scratch/job_98763/pfd_h6mp91h7/15 --gzip ERR4231012
# Read 4595997 spots for ERR4231012
# Written 4595997 spots for ERR4231012
# Read 4595997 spots for ERR4231012
# Written 4595997 spots for ERR4231012
# Read 4595997 spots for ERR4231012
# Written 4595997 spots for ERR4231012
# Read 4595997 spots for ERR4231012
# Written 4595997 spots for ERR4231012
# Read 4595997 spots for ERR4231012
# Written 4595997 spots for ERR4231012
# Read 4595997 spots for ERR4231012
# Written 4595997 spots for ERR4231012
# Read 4595997 spots for ERR4231012
# Written 4595997 spots for ERR4231012
# Read 4595999 spots for ERR4231012
# Written 4595999 spots for ERR4231012
# Read 4595997 spots for ERR4231012
# Written 4595997 spots for ERR4231012
# Read 4595997 spots for ERR4231012
# Written 4595997 spots for ERR4231012
# Read 4595997 spots for ERR4231012
# Written 4595997 spots for ERR4231012
# Read 4595997 spots for ERR4231012
# Written 4595997 spots for ERR4231012
# Read 4595997 spots for ERR4231012
# Written 4595997 spots for ERR4231012
# Read 4595997 spots for ERR4231012
# Written 4595997 spots for ERR4231012
# Read 4595997 spots for ERR4231012
# Written 4595997 spots for ERR4231012
# Read 4595997 spots for ERR4231012
# Written 4595997 spots for ERR4231012
# Getting ERR4231013 from NCBI SRA
# 2024-10-10 16:19:58,609 - SRR ids: ['ERR4231013']
# 2024-10-10 16:19:58,609 - extra args: ['--gzip']
# 2024-10-10 16:19:58,609 - tempdir: /local/scratch/job_98763/pfd_04ghrruz
# 2024-10-10 16:19:58,609 - CMD: sra-stat --meta --quick ERR4231013
# 2024-10-10 16:20:01,014 - ERR4231013 spots: 62889838
# 2024-10-10 16:20:01,015 - blocks: [[1, 3930614], [3930615, 7861228], [7861229, 11791842], [11791843, 15722456], [15722457, 19653070], [19653071, 23583684], [23583685, 27514298], [27514299, 31444912], [31444913, 35375526], [35375527, 39306140], [39306141, 43236754], [43236755, 47167368], [47167369, 51097982], [51097983, 55028596], [55028597, 58959210], [58959211, 62889838]]
# 2024-10-10 16:20:01,015 - CMD: fastq-dump -N 1 -X 3930614 -O /local/scratch/job_98763/pfd_04ghrruz/0 --gzip ERR4231013
# 2024-10-10 16:20:01,015 - CMD: fastq-dump -N 3930615 -X 7861228 -O /local/scratch/job_98763/pfd_04ghrruz/1 --gzip ERR4231013
# 2024-10-10 16:20:01,016 - CMD: fastq-dump -N 7861229 -X 11791842 -O /local/scratch/job_98763/pfd_04ghrruz/2 --gzip ERR4231013
# 2024-10-10 16:20:01,017 - CMD: fastq-dump -N 11791843 -X 15722456 -O /local/scratch/job_98763/pfd_04ghrruz/3 --gzip ERR4231013
# 2024-10-10 16:20:01,017 - CMD: fastq-dump -N 15722457 -X 19653070 -O /local/scratch/job_98763/pfd_04ghrruz/4 --gzip ERR4231013
# 2024-10-10 16:20:01,017 - CMD: fastq-dump -N 19653071 -X 23583684 -O /local/scratch/job_98763/pfd_04ghrruz/5 --gzip ERR4231013
# 2024-10-10 16:20:01,018 - CMD: fastq-dump -N 23583685 -X 27514298 -O /local/scratch/job_98763/pfd_04ghrruz/6 --gzip ERR4231013
# 2024-10-10 16:20:01,018 - CMD: fastq-dump -N 27514299 -X 31444912 -O /local/scratch/job_98763/pfd_04ghrruz/7 --gzip ERR4231013
# 2024-10-10 16:20:01,020 - CMD: fastq-dump -N 31444913 -X 35375526 -O /local/scratch/job_98763/pfd_04ghrruz/8 --gzip ERR4231013
# 2024-10-10 16:20:01,020 - CMD: fastq-dump -N 35375527 -X 39306140 -O /local/scratch/job_98763/pfd_04ghrruz/9 --gzip ERR4231013
# 2024-10-10 16:20:01,020 - CMD: fastq-dump -N 39306141 -X 43236754 -O /local/scratch/job_98763/pfd_04ghrruz/10 --gzip ERR4231013
# 2024-10-10 16:20:01,021 - CMD: fastq-dump -N 43236755 -X 47167368 -O /local/scratch/job_98763/pfd_04ghrruz/11 --gzip ERR4231013
# 2024-10-10 16:20:01,022 - CMD: fastq-dump -N 47167369 -X 51097982 -O /local/scratch/job_98763/pfd_04ghrruz/12 --gzip ERR4231013
# 2024-10-10 16:20:01,023 - CMD: fastq-dump -N 51097983 -X 55028596 -O /local/scratch/job_98763/pfd_04ghrruz/13 --gzip ERR4231013
# 2024-10-10 16:20:01,023 - CMD: fastq-dump -N 55028597 -X 58959210 -O /local/scratch/job_98763/pfd_04ghrruz/14 --gzip ERR4231013
# 2024-10-10 16:20:01,059 - CMD: fastq-dump -N 58959211 -X 62889838 -O /local/scratch/job_98763/pfd_04ghrruz/15 --gzip ERR4231013
# Read 3930614 spots for ERR4231013
# Written 3930614 spots for ERR4231013
# Read 3930614 spots for ERR4231013
# Written 3930614 spots for ERR4231013
# Read 3930614 spots for ERR4231013
# Written 3930614 spots for ERR4231013
# Read 3930614 spots for ERR4231013
# Written 3930614 spots for ERR4231013
# Read 3930614 spots for ERR4231013
# Written 3930614 spots for ERR4231013
# Read 3930614 spots for ERR4231013
# Written 3930614 spots for ERR4231013
# Read 3930614 spots for ERR4231013
# Written 3930614 spots for ERR4231013
# Read 3930614 spots for ERR4231013
# Written 3930614 spots for ERR4231013
# Read 3930614 spots for ERR4231013
# Written 3930614 spots for ERR4231013
# Read 3930614 spots for ERR4231013
# Written 3930614 spots for ERR4231013
# Read 3930614 spots for ERR4231013
# Written 3930614 spots for ERR4231013
# Read 3930614 spots for ERR4231013
# Written 3930614 spots for ERR4231013
# Read 3930614 spots for ERR4231013
# Written 3930614 spots for ERR4231013
# Read 3930614 spots for ERR4231013
# Written 3930614 spots for ERR4231013
# Read 3930614 spots for ERR4231013
# Written 3930614 spots for ERR4231013
# Read 3930628 spots for ERR4231013
# Written 3930628 spots for ERR4231013
# Getting ERR4231014 from NCBI SRA
# 2024-10-10 16:28:48,803 - SRR ids: ['ERR4231014']
# 2024-10-10 16:28:48,803 - extra args: ['--gzip']
# 2024-10-10 16:28:48,804 - tempdir: /local/scratch/job_98763/pfd_7cy0f8c8
# 2024-10-10 16:28:48,804 - CMD: sra-stat --meta --quick ERR4231014
# 2024-10-10 16:28:51,171 - ERR4231014 spots: 36185523
# 2024-10-10 16:28:51,171 - blocks: [[1, 2261595], [2261596, 4523190], [4523191, 6784785], [6784786, 9046380], [9046381, 11307975], [11307976, 13569570], [13569571, 15831165], [15831166, 18092760], [18092761, 20354355], [20354356, 22615950], [22615951, 24877545], [24877546, 27139140], [27139141, 29400735], [29400736, 31662330], [31662331, 33923925], [33923926, 36185523]]
# 2024-10-10 16:28:51,171 - CMD: fastq-dump -N 1 -X 2261595 -O /local/scratch/job_98763/pfd_7cy0f8c8/0 --gzip ERR4231014
# 2024-10-10 16:28:51,172 - CMD: fastq-dump -N 2261596 -X 4523190 -O /local/scratch/job_98763/pfd_7cy0f8c8/1 --gzip ERR4231014
# 2024-10-10 16:28:51,172 - CMD: fastq-dump -N 4523191 -X 6784785 -O /local/scratch/job_98763/pfd_7cy0f8c8/2 --gzip ERR4231014
# 2024-10-10 16:28:51,173 - CMD: fastq-dump -N 6784786 -X 9046380 -O /local/scratch/job_98763/pfd_7cy0f8c8/3 --gzip ERR4231014
# 2024-10-10 16:28:51,173 - CMD: fastq-dump -N 9046381 -X 11307975 -O /local/scratch/job_98763/pfd_7cy0f8c8/4 --gzip ERR4231014
# 2024-10-10 16:28:51,174 - CMD: fastq-dump -N 11307976 -X 13569570 -O /local/scratch/job_98763/pfd_7cy0f8c8/5 --gzip ERR4231014
# 2024-10-10 16:28:51,176 - CMD: fastq-dump -N 13569571 -X 15831165 -O /local/scratch/job_98763/pfd_7cy0f8c8/6 --gzip ERR4231014
# 2024-10-10 16:28:51,176 - CMD: fastq-dump -N 15831166 -X 18092760 -O /local/scratch/job_98763/pfd_7cy0f8c8/7 --gzip ERR4231014
# 2024-10-10 16:28:51,177 - CMD: fastq-dump -N 18092761 -X 20354355 -O /local/scratch/job_98763/pfd_7cy0f8c8/8 --gzip ERR4231014
# 2024-10-10 16:28:51,205 - CMD: fastq-dump -N 20354356 -X 22615950 -O /local/scratch/job_98763/pfd_7cy0f8c8/9 --gzip ERR4231014
# 2024-10-10 16:28:51,208 - CMD: fastq-dump -N 22615951 -X 24877545 -O /local/scratch/job_98763/pfd_7cy0f8c8/10 --gzip ERR4231014
# 2024-10-10 16:28:51,209 - CMD: fastq-dump -N 24877546 -X 27139140 -O /local/scratch/job_98763/pfd_7cy0f8c8/11 --gzip ERR4231014
# 2024-10-10 16:28:51,237 - CMD: fastq-dump -N 27139141 -X 29400735 -O /local/scratch/job_98763/pfd_7cy0f8c8/12 --gzip ERR4231014
# 2024-10-10 16:28:51,237 - CMD: fastq-dump -N 29400736 -X 31662330 -O /local/scratch/job_98763/pfd_7cy0f8c8/13 --gzip ERR4231014
# 2024-10-10 16:28:51,238 - CMD: fastq-dump -N 31662331 -X 33923925 -O /local/scratch/job_98763/pfd_7cy0f8c8/14 --gzip ERR4231014
# 2024-10-10 16:28:51,239 - CMD: fastq-dump -N 33923926 -X 36185523 -O /local/scratch/job_98763/pfd_7cy0f8c8/15 --gzip ERR4231014
# Read 2261595 spots for ERR4231014
# Written 2261595 spots for ERR4231014
# Read 2261595 spots for ERR4231014
# Written 2261595 spots for ERR4231014
# Read 2261595 spots for ERR4231014
# Written 2261595 spots for ERR4231014
# Read 2261595 spots for ERR4231014
# Written 2261595 spots for ERR4231014
# Read 2261595 spots for ERR4231014
# Written 2261595 spots for ERR4231014
# Read 2261595 spots for ERR4231014
# Written 2261595 spots for ERR4231014
# Read 2261595 spots for ERR4231014
# Written 2261595 spots for ERR4231014
# Read 2261595 spots for ERR4231014
# Written 2261595 spots for ERR4231014
# Read 2261595 spots for ERR4231014
# Written 2261595 spots for ERR4231014
# Read 2261595 spots for ERR4231014
# Written 2261595 spots for ERR4231014
# Read 2261595 spots for ERR4231014
# Written 2261595 spots for ERR4231014
# Read 2261598 spots for ERR4231014
# Written 2261598 spots for ERR4231014
# Read 2261595 spots for ERR4231014
# Written 2261595 spots for ERR4231014
# Read 2261595 spots for ERR4231014
# Written 2261595 spots for ERR4231014
# Read 2261595 spots for ERR4231014
# Written 2261595 spots for ERR4231014
# Read 2261595 spots for ERR4231014
# Written 2261595 spots for ERR4231014
# Getting ERR4231015 from NCBI SRA
# 2024-10-10 16:33:54,146 - SRR ids: ['ERR4231015']
# 2024-10-10 16:33:54,146 - extra args: ['--gzip']
# 2024-10-10 16:33:54,146 - tempdir: /local/scratch/job_98763/pfd_y35yv3_q
# 2024-10-10 16:33:54,146 - CMD: sra-stat --meta --quick ERR4231015
# 2024-10-10 16:33:56,646 - ERR4231015 spots: 53650335
# 2024-10-10 16:33:56,646 - blocks: [[1, 3353145], [3353146, 6706290], [6706291, 10059435], [10059436, 13412580], [13412581, 16765725], [16765726, 20118870], [20118871, 23472015], [23472016, 26825160], [26825161, 30178305], [30178306, 33531450], [33531451, 36884595], [36884596, 40237740], [40237741, 43590885], [43590886, 46944030], [46944031, 50297175], [50297176, 53650335]]
# 2024-10-10 16:33:56,646 - CMD: fastq-dump -N 1 -X 3353145 -O /local/scratch/job_98763/pfd_y35yv3_q/0 --gzip ERR4231015
# 2024-10-10 16:33:56,648 - CMD: fastq-dump -N 3353146 -X 6706290 -O /local/scratch/job_98763/pfd_y35yv3_q/1 --gzip ERR4231015
# 2024-10-10 16:33:56,649 - CMD: fastq-dump -N 6706291 -X 10059435 -O /local/scratch/job_98763/pfd_y35yv3_q/2 --gzip ERR4231015
# 2024-10-10 16:33:56,655 - CMD: fastq-dump -N 10059436 -X 13412580 -O /local/scratch/job_98763/pfd_y35yv3_q/3 --gzip ERR4231015
# 2024-10-10 16:33:56,655 - CMD: fastq-dump -N 13412581 -X 16765725 -O /local/scratch/job_98763/pfd_y35yv3_q/4 --gzip ERR4231015
# 2024-10-10 16:33:56,657 - CMD: fastq-dump -N 16765726 -X 20118870 -O /local/scratch/job_98763/pfd_y35yv3_q/5 --gzip ERR4231015
# 2024-10-10 16:33:56,662 - CMD: fastq-dump -N 20118871 -X 23472015 -O /local/scratch/job_98763/pfd_y35yv3_q/6 --gzip ERR4231015
# 2024-10-10 16:33:56,664 - CMD: fastq-dump -N 23472016 -X 26825160 -O /local/scratch/job_98763/pfd_y35yv3_q/7 --gzip ERR4231015
# 2024-10-10 16:33:56,665 - CMD: fastq-dump -N 26825161 -X 30178305 -O /local/scratch/job_98763/pfd_y35yv3_q/8 --gzip ERR4231015
# 2024-10-10 16:33:56,687 - CMD: fastq-dump -N 30178306 -X 33531450 -O /local/scratch/job_98763/pfd_y35yv3_q/9 --gzip ERR4231015
# 2024-10-10 16:33:56,688 - CMD: fastq-dump -N 33531451 -X 36884595 -O /local/scratch/job_98763/pfd_y35yv3_q/10 --gzip ERR4231015
# 2024-10-10 16:33:56,710 - CMD: fastq-dump -N 36884596 -X 40237740 -O /local/scratch/job_98763/pfd_y35yv3_q/11 --gzip ERR4231015
# 2024-10-10 16:33:56,711 - CMD: fastq-dump -N 40237741 -X 43590885 -O /local/scratch/job_98763/pfd_y35yv3_q/12 --gzip ERR4231015
# 2024-10-10 16:33:56,711 - CMD: fastq-dump -N 43590886 -X 46944030 -O /local/scratch/job_98763/pfd_y35yv3_q/13 --gzip ERR4231015
# 2024-10-10 16:33:56,712 - CMD: fastq-dump -N 46944031 -X 50297175 -O /local/scratch/job_98763/pfd_y35yv3_q/14 --gzip ERR4231015
# 2024-10-10 16:33:56,713 - CMD: fastq-dump -N 50297176 -X 53650335 -O /local/scratch/job_98763/pfd_y35yv3_q/15 --gzip ERR4231015
# Read 3353145 spots for ERR4231015
# Written 3353145 spots for ERR4231015
# Read 3353145 spots for ERR4231015
# Written 3353145 spots for ERR4231015
# Read 3353145 spots for ERR4231015
# Written 3353145 spots for ERR4231015
# Read 3353145 spots for ERR4231015
# Written 3353145 spots for ERR4231015
# Read 3353145 spots for ERR4231015
# Written 3353145 spots for ERR4231015
# Read 3353145 spots for ERR4231015
# Written 3353145 spots for ERR4231015
# Read 3353145 spots for ERR4231015
# Written 3353145 spots for ERR4231015
# Read 3353145 spots for ERR4231015
# Written 3353145 spots for ERR4231015
# Read 3353145 spots for ERR4231015
# Written 3353145 spots for ERR4231015
# Read 3353160 spots for ERR4231015
# Written 3353160 spots for ERR4231015
# Read 3353145 spots for ERR4231015
# Written 3353145 spots for ERR4231015
# Read 3353145 spots for ERR4231015
# Written 3353145 spots for ERR4231015
# Read 3353145 spots for ERR4231015
# Written 3353145 spots for ERR4231015
# Read 3353145 spots for ERR4231015
# Written 3353145 spots for ERR4231015
# Read 3353145 spots for ERR4231015
# Written 3353145 spots for ERR4231015
# Read 3353145 spots for ERR4231015
# Written 3353145 spots for ERR4231015
# Getting ERR4231016 from NCBI SRA
# 2024-10-10 16:41:10,012 - SRR ids: ['ERR4231016']
# 2024-10-10 16:41:10,012 - extra args: ['--gzip']
# 2024-10-10 16:41:10,012 - tempdir: /local/scratch/job_98763/pfd_hk4p1800
# 2024-10-10 16:41:10,012 - CMD: sra-stat --meta --quick ERR4231016
# 2024-10-10 16:41:12,624 - ERR4231016 spots: 51945229
# 2024-10-10 16:41:12,624 - blocks: [[1, 3246576], [3246577, 6493152], [6493153, 9739728], [9739729, 12986304], [12986305, 16232880], [16232881, 19479456], [19479457, 22726032], [22726033, 25972608], [25972609, 29219184], [29219185, 32465760], [32465761, 35712336], [35712337, 38958912], [38958913, 42205488], [42205489, 45452064], [45452065, 48698640], [48698641, 51945229]]
# 2024-10-10 16:41:12,624 - CMD: fastq-dump -N 1 -X 3246576 -O /local/scratch/job_98763/pfd_hk4p1800/0 --gzip ERR4231016
# 2024-10-10 16:41:12,625 - CMD: fastq-dump -N 3246577 -X 6493152 -O /local/scratch/job_98763/pfd_hk4p1800/1 --gzip ERR4231016
# 2024-10-10 16:41:12,625 - CMD: fastq-dump -N 6493153 -X 9739728 -O /local/scratch/job_98763/pfd_hk4p1800/2 --gzip ERR4231016
# 2024-10-10 16:41:12,626 - CMD: fastq-dump -N 9739729 -X 12986304 -O /local/scratch/job_98763/pfd_hk4p1800/3 --gzip ERR4231016
# 2024-10-10 16:41:12,626 - CMD: fastq-dump -N 12986305 -X 16232880 -O /local/scratch/job_98763/pfd_hk4p1800/4 --gzip ERR4231016
# 2024-10-10 16:41:12,626 - CMD: fastq-dump -N 16232881 -X 19479456 -O /local/scratch/job_98763/pfd_hk4p1800/5 --gzip ERR4231016
# 2024-10-10 16:41:12,626 - CMD: fastq-dump -N 19479457 -X 22726032 -O /local/scratch/job_98763/pfd_hk4p1800/6 --gzip ERR4231016
# 2024-10-10 16:41:12,627 - CMD: fastq-dump -N 22726033 -X 25972608 -O /local/scratch/job_98763/pfd_hk4p1800/7 --gzip ERR4231016
# 2024-10-10 16:41:12,627 - CMD: fastq-dump -N 25972609 -X 29219184 -O /local/scratch/job_98763/pfd_hk4p1800/8 --gzip ERR4231016
# 2024-10-10 16:41:12,627 - CMD: fastq-dump -N 29219185 -X 32465760 -O /local/scratch/job_98763/pfd_hk4p1800/9 --gzip ERR4231016
# 2024-10-10 16:41:12,628 - CMD: fastq-dump -N 32465761 -X 35712336 -O /local/scratch/job_98763/pfd_hk4p1800/10 --gzip ERR4231016
# 2024-10-10 16:41:12,628 - CMD: fastq-dump -N 35712337 -X 38958912 -O /local/scratch/job_98763/pfd_hk4p1800/11 --gzip ERR4231016
# 2024-10-10 16:41:12,628 - CMD: fastq-dump -N 38958913 -X 42205488 -O /local/scratch/job_98763/pfd_hk4p1800/12 --gzip ERR4231016
# 2024-10-10 16:41:12,628 - CMD: fastq-dump -N 42205489 -X 45452064 -O /local/scratch/job_98763/pfd_hk4p1800/13 --gzip ERR4231016
# 2024-10-10 16:41:12,669 - CMD: fastq-dump -N 45452065 -X 48698640 -O /local/scratch/job_98763/pfd_hk4p1800/14 --gzip ERR4231016
# 2024-10-10 16:41:12,702 - CMD: fastq-dump -N 48698641 -X 51945229 -O /local/scratch/job_98763/pfd_hk4p1800/15 --gzip ERR4231016

# %% [markdown]
# Edit this block with a short evaluation of each of the report sections. Each evaluation should include your important observations, reasons for potential QC failure, and an opinion on what should be done on the failure (i.e., trimming or filtering). Problem FASTQ files, if any, should be noted.
#
# *Per base sequence quality:*
#
# *Per tile sequence quality:*
#
# *Per sequence quality scores:*
#
# *Per base sequence content:*
#
# *Per sequence GC content:*
#
# *Per base N content:*
#
# *Sequence length distribution:*
#
# *Sequence duplication levels:*
#
# *Overrepresented sequences:*
#
# *Adapter content:*

# %% [markdown]
# If necessary, use `cutadapt` to trim and filter your reads. Provide a justification for the `cutadapt` parameters you used:

# %%
# !mkdir fastq_placenta/placenta_qc
# !fastqc -t 16 fastq/*.fastq.gz -o fastq_placenta/placenta_qc

# %% [markdown]
# Run QC on the trimmed/filtered reads and generate an aggregated report

# %% [markdown]
# Report your observations on which QC metrics improved (or got worse):

# %% [markdown]
# ## Snakemake Pipeline

# %% [markdown]
# When running bioinformatics studies, it is wise to use notebooks (such as this one) to tie together code, decisions, and data visualization. The above task is something you might generate and report to a client or supervisor who might be interested in sequencing QC and what kind of pre-processing decisions you made prior to alignment. In addition, the preprocessing should be readily reproducible by all relevant stakeholders, so you should supplement notebooks with pipeline scripts. Throughout the semester, we will be creating snakemake pipelines to reproduce the published analysis that you've selected. Follow the below steps to begin producing this pipeline:
#
# 1. Make a new `Snakefile` and `config.yaml` in `4_fastq`.
# 2. In the `Snakefile`, produce the following rules:
#     a. `fetch_fastq` - use `parallel-fastq-dump` to fetch every FASTQ file listed in `config.yaml`.
#     b. `fastq_qc` - use `fastqc` to run QC on the raw FASTQ files.
#     c. `trim_filter` - use `cutadapt` to trim and/or filter the FASTQ reads, using parameters justified in this notebook. ***Note:*** if you choose to trim/filter, it should be done on *all* of the FASTQ files; do not cherry pick.
#     d. `trim_qc` - use `fastqc` to run QC on the trimmed FASTQ files.
#     e. `report` - use `multiqc` to aggregate all QC data into a single report. .
#
# This `Snakefile` should not use any `wrappers` because we already have the relevant software installed in the `biol343` conda environment. The pipeline should run to completion when any instructor or classmate runs `snakemake --use-conda`. You may use the documentation found [here](https://multiqc.info/docs/usage/pipelines/#snakemake) or any other online documentation you may find. You may not use any AI tools to complete this homework.
